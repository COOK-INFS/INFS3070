# %%
import pandas as pd

dfTitles = pd.read_csv('http://infs3080-class.uccs.edu/pydev/dataFiles/IMDB/titleBasics.tsv', sep='\t', low_memory=False)
dfRatings = pd.read_csv('http://infs3080-class.uccs.edu/pydev/dataFiles/IMDB/ratings.tsv', sep='\t', low_memory=False)
dfNames = pd.read_csv('http://infs3080-class.uccs.edu/pydev/dataFiles/IMDB/nameBasics.tsv', sep='\t', low_memory=False)
dfCrew = pd.read_csv('http://infs3080-class.uccs.edu/pydev/dataFiles/IMDB/crew.tsv', sep='\t', low_memory=False)

# %% [markdown]
# # Get to know our data set

# %% [markdown]
# ![Homework3_ERD.png](./Homework3_ERD.png)

# %% [markdown]
# # Question 1: Director with the highest rating and most votes

# %%
dfNames.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0045537,tt0050419,tt0053137,tt0072308
# 1  tt0117057,tt0071877,tt0038355,tt0037382
# 2  tt0054452,tt0056404,tt0049189,tt0057345
# 3  tt0078723,tt0080455,tt0072562,tt0077975
# 4  tt0050986,tt0050976,tt0060827,tt0083922

# %%
dfCrew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %% [markdown]
# ## Merge 'Ratings' and 'Crew'

# %%
ratingsAndCrew = pd.merge(dfRatings, dfCrew, on='tconst')

ratingsAndCrew
# Out:
#             tconst  averageRating  numVotes   directors              writers
# 0        tt0000001            5.7      1957   nm0005690                   \N
# 1        tt0000002            5.8       263   nm0721526                   \N
# 2        tt0000003            6.5      1790   nm0721526                   \N
# 3        tt0000004            5.6       179   nm0721526                   \N
# 4        tt0000005            6.2      2593   nm0005690                   \N
# ...            ...            ...       ...         ...                  ...
# 1284586  tt9916730            8.3        10  nm10538612           nm10538612
# 1284587  tt9916766            7.0        21          \N                   \N
# 1284588  tt9916778            7.2        36          \N                   \N
# 1284589  tt9916840            8.8         6   nm0996406  nm1482639,nm2586970
# 1284590  tt9916880            8.2         6   nm0996406  nm1482639,nm2586970
#
# [1284591 rows x 5 columns]

# %% [markdown]
# ## Renaming the 'Directors' column

# %%
dfCrewRename = ratingsAndCrew.rename(columns={'directors': 'nconst'})

dfCrewRename
# Out:
#             tconst  averageRating  numVotes      nconst              writers
# 0        tt0000001            5.7      1957   nm0005690                   \N
# 1        tt0000002            5.8       263   nm0721526                   \N
# 2        tt0000003            6.5      1790   nm0721526                   \N
# 3        tt0000004            5.6       179   nm0721526                   \N
# 4        tt0000005            6.2      2593   nm0005690                   \N
# ...            ...            ...       ...         ...                  ...
# 1284586  tt9916730            8.3        10  nm10538612           nm10538612
# 1284587  tt9916766            7.0        21          \N                   \N
# 1284588  tt9916778            7.2        36          \N                   \N
# 1284589  tt9916840            8.8         6   nm0996406  nm1482639,nm2586970
# 1284590  tt9916880            8.2         6   nm0996406  nm1482639,nm2586970
#
# [1284591 rows x 5 columns]

# %% [markdown]
# ## Merging Director name information

# %%
ratingsCrewDir = pd.merge(dfCrewRename, dfNames, on='nconst')

ratingsCrewDir
# Out:
#            tconst  averageRating  numVotes      nconst  \
# 0       tt0000001            5.7      1957   nm0005690
# 1       tt0000005            6.2      2593   nm0005690
# 2       tt0000006            5.1       177   nm0005690
# 3       tt0000008            5.4      2096   nm0005690
# 4       tt0000036            4.4       603   nm0005690
# ...           ...            ...       ...         ...
# 919348  tt9915790            7.2        39  nm10538030
# 919349  tt9915872            7.3         8   nm8063415
# 919350  tt9916038            6.4        15   nm1517212
# 919351  tt9916170            7.0         7   nm5412267
# 919352  tt9916730            8.3        10  nm10538612
#
#                               writers           primaryName birthYear  \
# 0                                  \N  William K.L. Dickson      1860
# 1                                  \N  William K.L. Dickson      1860
# 2                                  \N  William K.L. Dickson      1860
# 3                                  \N  William K.L. Dickson      1860
# 4                           nm0410331  William K.L. Dickson      1860
# ...                               ...                   ...       ...
# 919348                             \N     Sudipa Chatterjee        \N
# 919349                      nm2507310         Hideki Kiyota        \N
# 919350                     nm10538228       Aitor de Miguel        \N
# 919351  nm5412267,nm6743460,nm3245789       Tamar Guimaraes        \N
# 919352                     nm10538612          Kiran Gawade        \N
#
#        deathYear                  primaryProfession  \
# 0           1935  cinematographer,director,producer
# 1           1935  cinematographer,director,producer
# 2           1935  cinematographer,director,producer
# 3           1935  cinematographer,director,producer
# 4           1935  cinematographer,director,producer
# ...          ...                                ...
# 919348        \N                    writer,director
# 919349        \N           director,producer,writer
# 919350        \N           producer,director,writer
# 919351        \N             director,editor,writer
# 919352        \N                                NaN
#
#                                    knownForTitles
# 0         tt0219560,tt1496763,tt0308254,tt1428455
# 1         tt0219560,tt1496763,tt0308254,tt1428455
# 2         tt0219560,tt1496763,tt0308254,tt1428455
# 3         tt0219560,tt1496763,tt0308254,tt1428455
# 4         tt0219560,tt1496763,tt0308254,tt1428455
# ...                                           ...
# 919348                       tt9915790,tt10157608
# 919349  tt9915872,tt12020994,tt5624216,tt12035488
# 919350  tt13798564,tt10780342,tt5790722,tt4772108
# 919351             tt14333200,tt9916170,tt2568132
# 919352                                  tt9916730
#
# [919353 rows x 10 columns]

# %% [markdown]
# ## Sorting the information in the dataframe

# %%
ratingsCrewDir.sort_values(by=['averageRating', 'numVotes'], ascending=False)
# Out:
#            tconst  averageRating  numVotes     nconst  \
# 408832  tt2301451           10.0    190975  nm0426059
# 127057  tt0602889           10.0       744  nm0272564
# 557813  tt0602882           10.0       742  nm1973873
# 536631  tt0541970           10.0       735  nm0404241
# 412389  tt0541976           10.0       663  nm0322533
# ...           ...            ...       ...        ...
# 879383  tt4345906            1.0         5  nm7047141
# 887220  tt5092916            1.0         5  nm7636365
# 901196  tt7634626            1.0         5  nm4551964
# 910341  tt7812488            1.0         5  nm8203158
# 910342  tt7812820            1.0         5  nm8081188
#
#                               writers        primaryName birthYear deathYear  \
# 408832            nm0319213,nm0909124       Rian Johnson      1973        \N
# 127057  nm0356753,nm0715087,nm1661181  Nicholas Ferguson      1938        \N
# 557813                             \N        Paul Murphy        \N        \N
# 536631                      nm0430210   Martin Hutchings        \N        \N
# 412389                      nm0430210    Kenneth Glenaan        \N        \N
# ...                               ...                ...       ...       ...
# 879383            nm9739495,nm7567850       Jer Rucinski        \N        \N
# 887220                      nm7636365        James Jones        \N        \N
# 901196  nm3220091,nm4551964,nm3042557       Nathan Block        \N        \N
# 910341                             \N    Daniel Reynolds        \N        \N
# 910342                             \N  Victor Littlejohn        \N        \N
#
#                                  primaryProfession  \
# 408832                    producer,writer,director
# 127057          director,actor,production_designer
# 557813                           director,producer
# 536631   director,miscellaneous,production_manager
# 412389            director,actor,script_department
# ...                                            ...
# 879383                             director,editor
# 887220                       director,actor,writer
# 901196                    producer,director,writer
# 910341          writer,assistant_director,director
# 910342  camera_department,actor,production_manager
#
#                                    knownForTitles
# 408832   tt1276104,tt2527336,tt11564570,tt8946378
# 127057    tt0163499,tt0318207,tt0053494,tt0320064
# 557813  tt0436992,tt1888075,tt15654810,tt13696808
# 536631    tt0167667,tt0259733,tt0106102,tt0849988
# 412389    tt1748888,tt1198144,tt0420333,tt0295275
# ...                                           ...
# 879383                                  tt4345906
# 887220                                  tt5092916
# 901196    tt9185750,tt7333314,tt8879504,tt8681662
# 910341    tt7159540,tt5808350,tt6468084,tt5939294
# 910342   tt8518340,tt5792328,tt10442872,tt5939294
#
# [919353 rows x 10 columns]

# %% [markdown]
# ## Output the results

# %%
semi1 = (ratingsCrewDir.sort_values(by=['averageRating', 'numVotes'], ascending=False))
         
semi2 = semi1[['primaryName', 'averageRating', 'numVotes']]
         
final = (semi2.head(1))
         
final
# Out:
#          primaryName  averageRating  numVotes
# 408832  Rian Johnson           10.0    190975

# %% [markdown]
# ## Write the results to a file

# %%
final.to_csv('question1.csv', index=False)

# %% [markdown]
# # Question 2: Highest rated film for the year 2000 by votes then rating?

# %%
dfTitles.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
dfRatings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1957
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1790
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2593

# %% [markdown]
# ## Merge dataframes

# %%
highRated = pd.merge(dfTitles, dfRatings, on='tconst')

highRated
# Out:
#             tconst  titleType                primaryTitle  \
# 0        tt0000001      short                  Carmencita
# 1        tt0000002      short      Le clown et ses chiens
# 2        tt0000003      short              Pauvre Pierrot
# 3        tt0000004      short                 Un bon bock
# 4        tt0000005      short            Blacksmith Scene
# ...            ...        ...                         ...
# 1284586  tt9916730      movie                      6 Gunn
# 1284587  tt9916766  tvEpisode              Episode #10.15
# 1284588  tt9916778  tvEpisode                      Escape
# 1284589  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 1284590  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              4
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 1284586                      6 Gunn       0      2017      \N            116
# 1284587              Episode #10.15       0      2019      \N             43
# 1284588                      Escape       0      2019      \N             \N
# 1284589  Horrid Henry's Comic Caper       0      2014      \N             11
# 1284590   Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres  averageRating  numVotes
# 0                  Documentary,Short            5.7      1957
# 1                    Animation,Short            5.8       263
# 2           Animation,Comedy,Romance            6.5      1790
# 3                    Animation,Short            5.6       179
# 4                       Comedy,Short            6.2      2593
# ...                              ...            ...       ...
# 1284586                           \N            8.3        10
# 1284587  Family,Game-Show,Reality-TV            7.0        21
# 1284588          Crime,Drama,Mystery            7.2        36
# 1284589   Adventure,Animation,Comedy            8.8         6
# 1284590   Adventure,Animation,Comedy            8.2         6
#
# [1284591 rows x 11 columns]

# %% [markdown]
# ## Query to remove everything except movies in the year 2000.

# %%
movieFilter = (highRated.query('titleType == "movie" & startYear == "2000"'))

movieFilter
# Out:
#             tconst titleType                 primaryTitle  \
# 4191     tt0015414     movie       La tierra de los toros
# 75077    tt0102362     movie                       Istota
# 83871    tt0113026     movie              The Fantasticks
# 83917    tt0113086     movie       Florentino y el diablo
# 83922    tt0113092     movie                For the Cause
# ...            ...       ...                          ...
# 1253024  tt9002028     movie             Kannukku Kannaga
# 1253036  tt9002116     movie            Karisakattu Poove
# 1253853  tt9021032     movie  Koodi Vazhnthal Kodi Nanmai
# 1264309  tt9257896     movie               Punaradhivasam
# 1271816  tt9486348     movie            Cinema Enthusiast
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 4191          La tierra de los toros       0      2000      \N             60
# 75077                         Istota       0      2000      \N             80
# 83871                The Fantasticks       0      2000      \N             86
# 83917         Florentino y el diablo       0      2000      \N             \N
# 83922                  For the Cause       0      2000      \N            100
# ...                              ...     ...       ...     ...            ...
# 1253024             Kannukku Kannaga       0      2000      \N            130
# 1253036            Karisakattu Poove       0      2000      \N            140
# 1253853  Koodi Vazhnthal Kodi Nanmai       0      2000      \N            155
# 1264309               Punaradhivasam       0      2000      \N             \N
# 1271816            Cinema Enthusiast       0      2000      \N             95
#
#                          genres  averageRating  numVotes
# 4191                         \N            5.3        16
# 75077             Drama,Romance            6.3        17
# 83871           Musical,Romance            5.6      1395
# 83917                     Drama            6.8        21
# 83922    Action,Adventure,Drama            3.4       835
# ...                         ...            ...       ...
# 1253024                   Drama            4.8         6
# 1253036                   Drama            4.6         8
# 1253853                   Drama            6.4        41
# 1264309                      \N            6.9        11
# 1271816     Action,Comedy,Drama            4.5        66
#
# [3241 rows x 11 columns]

# %% [markdown]
# ## Sort the values

# %%
movieFilter.sort_values(by=['numVotes', 'averageRating'], ascending=False)
# Out:
#             tconst titleType                     primaryTitle  \
# 116524   tt0172495     movie                        Gladiator
# 134960   tt0209144     movie                          Memento
# 134475   tt0208092     movie                           Snatch
# 120345   tt0180093     movie              Requiem for a Dream
# 102120   tt0144084     movie                  American Psycho
# ...            ...       ...                              ...
# 150066   tt0243207     movie                  Daydream Nation
# 513424  tt11260742     movie            Duvarlar-Mauern-Walls
# 525583  tt11496658     movie                   Cosmos and Man
# 561226  tt12227980     movie  The Temptation of Office Ladies
# 452358  tt10137486     movie              An Eyes for an Eyes
#
#                           originalTitle isAdult startYear endYear  \
# 116524                        Gladiator       0      2000      \N
# 134960                          Memento       0      2000      \N
# 134475                           Snatch       0      2000      \N
# 120345              Requiem for a Dream       0      2000      \N
# 102120                  American Psycho       0      2000      \N
# ...                                 ...     ...       ...     ...
# 150066                  Daydream Nation       0      2000      \N
# 513424            Duvarlar-Mauern-Walls       0      2000      \N
# 525583                   Cosmos and Man       0      2000      \N
# 561226  The Temptation of Office Ladies       0      2000      \N
# 452358                  Yi yan huan yan       0      2000      \N
#
#        runtimeMinutes                  genres  averageRating  numVotes
# 116524            155  Action,Adventure,Drama            8.5   1515747
# 134960            113        Mystery,Thriller            8.4   1249899
# 134475            104            Comedy,Crime            8.2    864845
# 120345            102                   Drama            8.3    851608
# 102120            102      Crime,Drama,Horror            7.6    639139
# ...               ...                     ...            ...       ...
# 150066            105                      \N            7.4         5
# 513424             83             Documentary            7.2         5
# 525583             \N             Documentary            7.0         5
# 561226             87                Thriller            4.6         5
# 452358             84        Mystery,Thriller            4.2         5
#
# [3241 rows x 11 columns]

# %% [markdown]
# ## Format the results for output

# %%
semi1 = (movieFilter.sort_values(by=['numVotes', 'averageRating'], ascending=False))

semi2 = semi1[['startYear', 'primaryTitle', 'numVotes', 'averageRating']]

final=(semi2.head(5))

final
# Out:
#        startYear         primaryTitle  numVotes  averageRating
# 116524      2000            Gladiator   1515747            8.5
# 134960      2000              Memento   1249899            8.4
# 134475      2000               Snatch    864845            8.2
# 120345      2000  Requiem for a Dream    851608            8.3
# 102120      2000      American Psycho    639139            7.6

# %% [markdown]
# ## Output the results to a file.

# %%
final.to_csv('question2.csv', index=False)
